# %%
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from path import Path

# %%
basedir = Path("../data/sims/one_sided/three_eq/")
outdir = Path("../data/sims/one_sided/three_eq_last/").mkdir_p()
for file in basedir.files():
    df = pd.read_csv(file)
    df = df[df.t == df.t.max()].set_index("x").drop("t", axis=1)
    df.to_csv(outdir / file.basename())

# %%
df = pd.read_csv("../data/sims/one_sided_long/three_eq/Da=0.01_Ka=769.8_L=2000.0_Re=50.0_buffer_len=0.0_fnoise=10.0_tmax=5000.0_Δt=2.0_Δx=0.5_δ=0.5_εₕ=0.78_θ=0.08_ξ=1.0.csv")
df = df[df.t == df.t.max()].set_index("x").drop("t", axis=1)
ds = df.to_xarray()

# %%
ds["qₗ"].plot()
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
fig, ax = plt.subplots(figsize=(10, 3))
ds["qₚ"].plot(ax=ax)
ds["qₗ"].plot(ax=ax)
# ax.set_xlim(0, 100.0)
# ax.set_ylim(0, 1.8)
# %%
