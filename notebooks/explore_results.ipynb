# %%
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
from path import Path

# %%
df = pd.read_csv("../data/sims/one_sided_long/three_eq/Da=0.001_Ka=770.0_L=2000.0_Re=50.0_buffer_len=0.0_fnoise=10.0_tmax=5000.0_Δt=2.0_Δx=0.5_δ=0.5_εₕ=0.78_θ=0.0803_ξ=1.0.csv")
df = df[df.t == df.t.max()].set_index("x").drop("t", axis=1)
ds = df.to_xarray()

# %%
ds["h"].plot()
# plt.ylim(0, 1)

# %%
fig, ax = plt.subplots(figsize=(10, 3))
ds["qₚ"].plot(ax=ax)
ds["qₗ"].plot(ax=ax)
# %%

# %%
fig, ax = plt.subplots(figsize=(10, 3))
ds.h.plot(ax=ax)
